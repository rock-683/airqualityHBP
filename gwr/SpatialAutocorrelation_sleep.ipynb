# %% [markdown]
# # Spatial Autocorrelation: Sleep
#
# `SLEEP_AdjP` - Model-based estimate for age-adjusted prevalence of sleeping less than 7 hours among adults aged >=18 years

# %%
pip install pysal==2.0.0
# Out:
# Requirement already satisfied: pysal==2.0.0 in /opt/conda/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from pysal==2.0.0) (3.5.3)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from pysal==2.0.0) (0.12.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from pysal==2.0.0) (0.25.2)
# Requirement already satisfied: palettable in /opt/conda/lib/python3.7/site-packages (from pysal==2.0.0) (3.3.0)
# Requirement already satisfied: scipy>=0.11 in /opt/conda/lib/python3.7/site-packages (from pysal==2.0.0) (1.7.3)
# Requirement already satisfied: descartes in /opt/conda/lib/python3.7/site-packages (from pysal==2.0.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->pysal==2.0.0) (0.10.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.7/site-packages (from matplotlib->pysal==2.0.0) (1.17.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->pysal==2.0.0) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->pysal==2.0.0) (1.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->pysal==2.0.0) (24.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->pysal==2.0.0) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->pysal==2.0.0) (2.8.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->pysal==2.0.0) (9.5.0)
# Requirement already satisfied: typing_extensions; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from seaborn->pysal==2.0.0) (4.7.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas->pysal==2.0.0) (2019.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->pysal==2.0.0) (1.12.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->pysal==2.0.0) (41.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install esda
# Out:
# Requirement already satisfied: esda in /opt/conda/lib/python3.7/site-packages (2.4.3)
# Requirement already satisfied: scipy>=0.11 in /opt/conda/lib/python3.7/site-packages (from esda) (1.7.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from esda) (0.25.2)
# Requirement already satisfied: libpysal in /opt/conda/lib/python3.7/site-packages (from esda) (4.7.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from esda) (1.0.2)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /opt/conda/lib/python3.7/site-packages (from scipy>=0.11->esda) (1.17.3)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas->esda) (2019.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas->esda) (2.8.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from libpysal->esda) (4.7.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from libpysal->esda) (24.0)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.7/site-packages (from libpysal->esda) (4.0.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from libpysal->esda) (2.10.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from libpysal->esda) (2.22.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->esda) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->esda) (1.3.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->esda) (1.12.0)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->libpysal->esda) (1.9.2)
# Requirement already satisfied: typing-extensions>=4.7.1; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from platformdirs->libpysal->esda) (4.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->libpysal->esda) (1.1.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->libpysal->esda) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->libpysal->esda) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->libpysal->esda) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->libpysal->esda) (2.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install splot   #this might take some time the first time
# Out:
# Collecting splot
#   Using cached https://files.pythonhosted.org/packages/94/c7/bc840c32ee973c4609465c1d8722f3e433653edf6aab65ba341cd59fcf34/splot-1.1.7-py3-none-any.whl
# Requirement already satisfied: mapclassify in /opt/conda/lib/python3.7/site-packages (from splot) (2.6.0)
# Requirement already satisfied: esda in /opt/conda/lib/python3.7/site-packages (from splot) (2.4.3)
# Requirement already satisfied: spreg in /opt/conda/lib/python3.7/site-packages (from splot) (1.3.2)
# Requirement already satisfied: libpysal in /opt/conda/lib/python3.7/site-packages (from splot) (4.7.0)
# Requirement already satisfied: matplotlib>=3.3.3 in /opt/conda/lib/python3.7/site-packages (from splot) (3.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.7/site-packages (from splot) (0.12.2)
# Requirement already satisfied: geopandas>=0.9.0 in /opt/conda/lib/python3.7/site-packages (from splot) (0.10.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from splot) (24.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from splot) (1.17.3)
# Collecting giddy (from splot)
#   Using cached https://files.pythonhosted.org/packages/51/a2/0fbdec8bc6e5dbafe5c775c069403b8cf4a26d650e7b1c256148cbf7ec6a/giddy-2.3.4-py3-none-any.whl
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.7/site-packages (from mapclassify->splot) (1.7.3)
# Collecting pandas>=1.0 (from mapclassify->splot)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.7/site-packages (from mapclassify->splot) (2.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from mapclassify->splot) (1.0.2)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from libpysal->splot) (4.7.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from libpysal->splot) (2.22.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from libpysal->splot) (2.10.1)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.7/site-packages (from libpysal->splot) (4.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.3->splot) (2.4.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.3->splot) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.3->splot) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.3->splot) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.3->splot) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=3.3.3->splot) (2.8.0)
# Requirement already satisfied: typing_extensions; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from seaborn>=0.11.0->splot) (4.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from geopandas>=0.9.0->splot) (2.4.0)
# Requirement already satisfied: shapely>=1.6 in /opt/conda/lib/python3.7/site-packages (from geopandas>=0.9.0->splot) (1.6.4.post2)
# Requirement already satisfied: fiona>=1.8 in /opt/conda/lib/python3.7/site-packages (from geopandas>=0.9.0->splot) (1.8.9.post2)
# Collecting quantecon>=0.4.7 (from giddy->splot)
#   Using cached https://files.pythonhosted.org/packages/0c/33/07044ad6529c01ce4fac032d2124d2815ead529fb95eb6616aed8c0a57c1/quantecon-0.10.1-py3-none-any.whl
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1.0->mapclassify->splot) (2019.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx->mapclassify->splot) (4.4.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->mapclassify->splot) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->mapclassify->splot) (3.1.0)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->libpysal->splot) (1.9.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->libpysal->splot) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->libpysal->splot) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->libpysal->splot) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->libpysal->splot) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->libpysal->splot) (1.1.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib>=3.3.3->splot) (1.12.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.3->splot) (41.0.1)
# Requirement already satisfied: attrs>=17 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9.0->splot) (19.1.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9.0->splot) (1.1.1)
# Requirement already satisfied: click<8,>=4.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9.0->splot) (7.0)
# Requirement already satisfied: munch in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9.0->splot) (2.3.2)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9.0->splot) (0.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.7/site-packages (from quantecon>=0.4.7->giddy->splot) (1.3)
# Collecting numba>=0.49.0 (from quantecon>=0.4.7->giddy->splot)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.7/site-packages (from sympy->quantecon>=0.4.7->giddy->splot) (1.1.0)
# Collecting importlib-metadata; python_version < "3.9" (from numba>=0.49.0->quantecon>=0.4.7->giddy->splot)
#   Using cached https://files.pythonhosted.org/packages/ff/94/64287b38c7de4c90683630338cf28f129decbba0a44f0c6db35a873c73c4/importlib_metadata-6.7.0-py3-none-any.whl
# Collecting llvmlite<0.40,>=0.39.0dev0 (from numba>=0.49.0->quantecon>=0.4.7->giddy->splot)
#   Using cached https://files.pythonhosted.org/packages/14/27/1468111538f33bd9fb13c0b2c1534c7a487cec8fadf14e318d73be18e4e1/llvmlite-0.39.1.tar.gz
# Collecting zipp>=0.5 (from importlib-metadata; python_version < "3.9"->numba>=0.49.0->quantecon>=0.4.7->giddy->splot)
#   Using cached https://files.pythonhosted.org/packages/5b/fa/c9e82bbe1af6266adf08afb563905eb87cab83fde00a0a08963510621047/zipp-3.15.0-py3-none-any.whl
# Building wheels for collected packages: llvmlite
#   Building wheel for llvmlite (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-83cdusok/llvmlite/setup.py'"'"'; __file__='"'"'/tmp/pip-install-83cdusok/llvmlite/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-4y7eotdr --python-tag cp37
#        cwd: /tmp/pip-install-83cdusok/llvmlite/
#   Complete output (11 lines):
#   running bdist_wheel
#   /opt/conda/bin/python /tmp/pip-install-83cdusok/llvmlite/ffi/build.py
#   LLVM version... Traceback (most recent call last):
#     File "/tmp/pip-install-83cdusok/llvmlite/ffi/build.py", line 226, in <module>
#       main()
#     File "/tmp/pip-install-83cdusok/llvmlite/ffi/build.py", line 216, in main
#       main_posix('linux', '.so')
#     File "/tmp/pip-install-83cdusok/llvmlite/ffi/build.py", line 135, in main_posix
#       raise RuntimeError(msg) from None
#   RuntimeError: Could not find a `llvm-config` binary. There are a number of reasons this could occur, please see: https://llvmlite.readthedocs.io/en/latest/admin-guide/install.html#using-pip for help.
#   error: command '/opt/conda/bin/python' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for llvmlite
#   Running setup.py clean for llvmlite
# Failed to build llvmlite
# ERROR: numba 0.56.4 has requirement numpy<1.24,>=1.18, but you'll have numpy 1.17.3 which is incompatible.
# Installing collected packages: zipp, importlib-metadata, llvmlite, numba, quantecon, giddy, splot, pandas
#   Found existing installation: llvmlite 0.27.1
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U plotly
# Out:
# Requirement already up-to-date: plotly in /opt/conda/lib/python3.7/site-packages (5.18.0)
# Requirement already satisfied, skipping upgrade: packaging in /opt/conda/lib/python3.7/site-packages (from plotly) (24.0)
# Requirement already satisfied, skipping upgrade: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly) (8.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Graphics
import matplotlib.pyplot as plt
import seaborn as sbn
from pysal.viz import splot
#from splot.esda import plot_moran

# Analysis
import geopandas as gpd  # Spatial data manipulation
import pandas as pd
import numpy as np
from pysal.explore import esda
from pysal.lib import weights
from numpy.random import seed

# %%
# %matplotlib inline
import plotly.graph_objects as go
import plotly.figure_factory as ff
#https://plotly.com/python/builtin-colorscales/

from matplotlib import colors

# %% [markdown]
# ### Load all data with geospatial (geometry) component included

# %%
df = gpd.read_file('fipsmerge_geo.shp')

pd.set_option("max_columns", None)
pd.set_option("max_rows", None)

df.head(2)
# Out:
#     FIPS STATE_NAME   COUNTY STATE_ABBR  ACCESS2_Ad  ARTHRITIS_  BINGE_AdjP  \
# 0  01001    Alabama  Autauga         AL        10.4        28.2        15.5
# 1  01003    Alabama  Baldwin         AL         9.5        26.4        17.8
#
#    BPHIGH_Adj  BPMED_AdjP  CANCER_Adj  CASTHMA_Ad  CERVICAL_A  CHD_AdjPre  \
# 0        37.2        65.3         6.3        10.2        84.3         5.7
# 1        32.7        62.8         6.3         9.9        85.3         5.5
#
#    CHECKUP_Ad  CHOLSCREEN  COLON_SCRE  COPD_AdjPr  COREM_AdjP  COREW_AdjP  \
# 0        76.0        85.1        71.5         6.8        44.0        41.3
# 1        72.6        85.2        71.5         6.5        55.8        40.8
#
#    CSMOKING_A  DENTAL_Adj  DEPRESSION  DIABETES_A  GHLTH_AdjP  HIGHCHOL_A  \
# 0        16.9        62.9        22.7        10.7        17.3        32.1
# 1        15.0        65.5        23.2         9.8        15.2        31.9
#
#    KIDNEY_Adj  LPA_AdjPre  MAMMOUSE_A  MHLTH_AdjP  OBESITY_Ad  PHLTH_AdjP  \
# 0         2.9        29.1        74.8        18.0        38.9        11.7
# 1         2.7        27.6        75.4        17.3        37.2        11.0
#
#    SLEEP_AdjP  STROKE_Adj  TEETHLOST_  HEARING_Ad  VISION_Adj  COGNITION_  \
# 0        37.5         3.0        12.7         6.0         4.7        14.3
# 1        35.1         2.7         9.9         6.0         4.0        13.3
#
#    MOBILITY_A  SELFCARE_A  INDEPLIVE_  DISABILITY      COUNTY_NAM  SchoolSegr  \
# 0        14.7         3.7         8.2        30.2  Autauga County    0.055262
# 1        13.2         3.1         7.2        29.1  Baldwin County    0.090175
#
#    ChildcareC  Dentists  HighSchool  SomeColleg  Unemployme  ChildrenIn  \
# 0    0.175268  0.000322    0.895845    0.596126    0.028169       0.161
# 1    0.171167  0.000476    0.910142    0.661050    0.029630       0.164
#
#    IncomeIneq  ChildrenSi  AirPolluti  DrinkingWa  DrivingAlo  LongCommut  \
# 0     4.79440    0.267662        10.0         0.0    0.864011       0.416
# 1     4.30071    0.186992         7.6         1.0    0.814019       0.376
#
#    Disconnect  GenderPayG  MedianHHIn  ChildrenFr  Residentia  Homeowners  \
# 0         NaN    0.684511       66444    0.412507   32.707131    0.742451
# 1    0.078527    0.740877       65658    0.463740   38.482766    0.771212
#
#    SevereHous  BroadbandA  Population  AgeBelow18  Age65Older     Black  \
# 0    0.127533    0.854639       59095    0.234064    0.160487  0.207310
# 1    0.109629    0.878564      239294    0.212183    0.214698  0.083679
#
#    AmericanIn     Asian  NativeHawa  Hispanic     White  NotProfici    Female  \
# 0    0.004586  0.012031    0.001185  0.033268  0.724545    0.002312  0.513783
# 1    0.008003  0.011225    0.000685  0.048417  0.831488    0.007597  0.513477
#
#     PrematureD  PoorFairHe  PoorPhysic  PoorMental  LowBirthwe  AdultSmoki  \
# 0  9407.948438       0.173    3.910265    5.703204    0.098713       0.169
# 1  8981.575353       0.152    3.730943    5.373666    0.081243       0.150
#
#    AdultObesi  FoodEnviro  PhysicalIn  AccesstoEx  ExcessiveD  AlcoholImp  \
# 0       0.389         6.7       0.291    0.544920    0.152378    0.290909
# 1       0.372         7.5       0.276    0.631293    0.164226    0.361446
#
#      STI  TeenBirths  Uninsured  PrimaryCar  Preventabl  Mammograph  \
# 0  577.0   20.908880   0.100186    0.000440      3915.0        0.40
# 1  317.6   20.202237   0.109971    0.000627      2799.0        0.44
#
#    FluVaccina  SocialAsso  InjuryDeat  AirPollu_1  HHighHousi  HHwOvercro  \
# 0        0.37   12.691429   68.033478        10.0    0.132084    0.016002
# 1        0.42    9.653397   77.507985         7.6    0.105648    0.015230
#
#    HHwLackKit  LifeExpect  PrematureA  ChildMorta  InfantMort  FrequentPh  \
# 0    0.015770   75.263497  472.283923   58.562128    6.834686       0.117
# 1    0.006366   76.738314  416.218912   54.035005    5.329250       0.110
#
#    DiabetesPr  HIVPrevale  FoodInsecu  DrugOverdo  UninsuredA  UninsuredC  \
# 0       0.107       218.0       0.133    9.350765    0.124074    0.040412
# 1       0.098       174.3       0.118   25.729422    0.133762    0.049369
#
#    HighScho_1  ChildrenEl  Resident_1  ChildCar_1  Homicides   Suicides  \
# 0    0.870000    0.279986   29.382404    5.726341   6.616163  17.457479
# 1    0.886517    0.369956   39.543961    6.231824   3.388203  18.790126
#
#    FirearmFat  MotorVehic  JuvenileAr  FormalJuve  InformalJu     Rural  \
# 0   17.362711   18.067215    4.838710        24.0         6.0  0.406768
# 1   14.343432   15.833332   20.305677       343.0       122.0  0.375865
#
#    AIRQUALTY_                                           geometry
# 0    8.535348  POLYGON ((-86.82067 32.34731, -86.81446 32.370...
# 1    8.263533  POLYGON ((-87.97309 31.16482, -87.93710 31.173...

# %%
#checking for missing values including the 67 Florida counties
df['SLEEP_AdjP'].isna().sum()
# Out:
# 0

# %%
# drop only rows that are missing data for sleep
df = df.dropna(subset=['SLEEP_AdjP'])

# %% [markdown]
# ### Create table for vaiable of interest: Sleep

# %%
# Index table on variable of interest "Sleep"
db = df.set_index("SLEEP_AdjP", drop=False)
db.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
db2 = db.to_crs(epsg=3857)

# %% [markdown]
# Here I am choosing contiguity/adjacency spatial weight, specifically **Queen contiguity**. I think because the data are counties, that adjacency/contguity spatial weights works well for this polygon data. Although, it may not present much of a difference here, I am choosing Queen over Rook as to include as neighboors those polygons that only share one or more vertices.

# %%
# spaital weights
w = weights.contiguity.Queen.from_dataframe(db2)

#standardize matrix
w.transform = 'R'

#finding the log transform of the data to get the "y"
y = db2['SLEEP_AdjP']
# Out:
# ('WARNING: ', 1186, ' is an island (no neighbors)')
# ('WARNING: ', 1192, ' is an island (no neighbors)')
# ('WARNING: ', 1836, ' is an island (no neighbors)')
# ('WARNING: ', 2946, ' is an island (no neighbors)')
# /opt/conda/lib/python3.7/site-packages/pysal/lib/weights/weights.py:168: UserWarning: There are 4 disconnected observations
#   Island ids: 1186, 1192, 1836, 2946
#   " Island ids: %s" % ', '.join(str(island) for island in self.islands))

# %%
# Finding the spatial lag and adding column ‘lag’
db2['lag'] = weights.lag_spatial(w,y)

# %% [markdown]
# Calculating a **global measure** of spatial autocorrelation - **Moran's I**

# %%
#Moran's I and p-value
mi = esda.Moran(db2['lag'], w)
mi

# %%
mi.I
# Out:
# 0.8118450134790874

# %%
mi.p_sim
# Out:
# 0.001

# %% [markdown]
# **Sleep (`SLEEP_AdjP`)** The p-value is .001, so we reject the null - the .81 pattern reached significance.

# %%
# Let's take a look at the Moran's I plot. Remember to look at the 4 quarters.
# finishing changing the code to match current variables

db2['lag'] = weights.spatial_lag.lag_spatial(w, db2['SLEEP_AdjP'])

# %%
# moran_scatterplot(mi);
f, ax = plt.subplots(1, figsize=(6, 6))
sbn.regplot(
    x="SLEEP_AdjP",
    y="lag",
    ci=None,
    data=db2,
    line_kws={"color": "r"},
)
ax.axvline(0, c="k", alpha=0.5)
ax.axhline(0, c="k", alpha=0.5)
ax.set_title("Moran Plot - % Leave")
plt.show()

# %% [markdown]
# Looking more locally for spatial autocorrelation using the Local Indicator of Spatial Autocorrelation (**LISA**).

# %%
lisa = esda.Moran_Local(db2['lag'], w)
# Out:
# /opt/conda/lib/python3.7/site-packages/pysal/explore/esda/moran.py:895: RuntimeWarning: invalid value encountered in true_divide
#   self.z_sim = (self.Is - self.EI_sim) / self.seI_sim
# /opt/conda/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1956: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0

# %% [markdown]
# Adding columns to our data for both significance and what quadrant the counties fell in.

# %%
# Break counties into significant or not
db2['significant'] = lisa.p_sim < 0.05
db2['significant'] = db2['significant'].astype('int').astype("str")


# Tag what quadrant they belong to
db2['quad'] = lisa.q

# %%
#reset index
db2.reset_index(drop=True, inplace=True)

# %%
# Pick only significant counties - assign '0' to non-significant

spots = []

for x in range(len(db2.significant)):
    for obs in db2['significant'][x]:
        if obs == "0":
            spots.append(0)
        if obs == '1':
            spots.append(db2['quad'][x])

db2['spots'] = spots

# check the unique values
db2.spots.unique()
# Out:
# array([1, 0, 3])

# %%
#Mapping from value to name (as a dict)
spots_labels = {
    0: "Non-Significant",
    1: "HH",
    2: "LH",
    3: "LL",
    4: "HL",
}

# %%
# Create column in `db` with labels for each polygon
db2["labels"] = pd.Series(
    # First initialise a Series using values and `db` index
    spots,
    index=db2.index
    # Then map each value to corresponding label based
    # on the `spots_labels` mapping
).map(spots_labels)
# Print top for inspection
db2["labels"].value_counts()
# Out:
# Non-Significant    1606
# LL                  783
# HH                  719
# Name: labels, dtype: int64

# %%
#Getting Total USCountyMap for background

USCountyMap = df[['FIPS','STATE_NAME','geometry']]
USCountyMap = USCountyMap.to_crs({'init':'epsg:3857'})

# %%
from matplotlib.colors import ListedColormap, BoundaryNorm

# Set up figure and axes
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(18, 9))
# Make the axes accessible with single indexing


# Subplot 1 #
# Choropleth of local statistics


# Plot gray county base
base = USCountyMap.plot(color='#EDECED', 
                      edgecolor='white',
ax=ax)

#Plot choropleth of local statistics
db2.plot(column='SLEEP_AdjP', 
         cmap= 'viridis_r',
         #norm = Normalize(vmin=1, vmax=13),
         edgecolor='white',
         linewidth=0.2,
         alpha=0.8,
         legend = True,
         legend_kwds={'format': '%.0f'},
ax=base

)

# Figure styling #
# Set title to each subplot
ax.set_axis_off()
ax.set_title('Local Statistics: Sleep'
    )
# Tight layout to minimise in-betwee white space
f.tight_layout()

#Save figure
#plt.savefig("us_sleep")
    
# Display the figure
plt.show()

# %%
from matplotlib.colors import ListedColormap, BoundaryNorm

# Set up figure and axes
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(18, 9))
# Make the axes accessible with single indexing


# Subplot 2 #
# Quadrant categories

# Plot gray county base
base = USCountyMap.plot(color='#EDECED', 
                      edgecolor='white',
ax=ax)

# Plot Quandrant colors 
db2.plot(column='labels', 
         cmap=ListedColormap(['#D7191C','#FDAE61', '#ABD9E9','#2C7BB6','#D3D3D3']), 
         #cmap=ListedColormap(['#2C7BB6','#FDAE61', '#ABD9E9','#2C7BB6','#D3D3D3']),
         edgecolor='white', 
         alpha=0.8,
         legend = True, 
ax=base
)

# Figure styling #
# Set title to each subplot
ax.set_axis_off()
ax.set_title(
    'Moran Cluster Map: Sleep Significant Hot Spots and Cold Spots'
    )
ax.get_legend().remove()
# Tight layout to minimise in-betwee white space
f.tight_layout()

#Save figure
#plt.savefig("us_sleep_hscs")
    
# Display the figure
plt.show()
